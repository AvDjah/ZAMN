# %%
import numpy as np
import pandas as pd

# %%
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score


iris = datasets.load_iris()
X = iris.data
Y = iris.target

# %%
#using scikit
reg = LogisticRegression()
reg.fit(X,Y)
Y_pred = reg.predict(X)
print(accuracy_score(Y,Y_pred))
# Out:
# 0.9733333333333334
# /home/arvind/.local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
b = 0
size = X.shape[0]
W = np.zeros(size)
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
def updateWeights(X,W,b,size,lr,itrs):
    A = 1/(1+np.exp(-(X.dot(W)+b)))
    tmp = (A-Y.T)
    tmp = np.reshape(tmp,size)
    dW = np.dot(X.T,tmp)/size
    db = np.sum(tmp)/size
    W = W - lr*dW
    b = b - lr*db
    return W,b

def train(X,W,b,itrs,lr):
    size = X.shape[0]
    for i in range(itrs):
        W,b = updateWeights(X,W,b,size,0.01,1000)
    return W,b

resW,resb = train(X,W,b,1000,0.01)

def predict( X ,b,W ) :    
        Z = 1 / ( 1 + np.exp( - ( X.dot( W ) + b ) ) )        
        Y = np.where( Z > 0.5, 1, 0 )        
        return Y

res = predict(X,resb,resW)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_20813/3653150324.py in <module>
#      15     return W,b
#      16
# ---> 17 resW,resb = train(X,W,b,1000,0.01)
#      18
#      19 def predict( X ,b,W ) :
#
# /tmp/ipykernel_20813/3653150324.py in train(X, W, b, itrs, lr)
#      12     size = X.shape[0]
#      13     for i in range(itrs):
# ---> 14         W,b = updateWeights(X,W,b,size,0.01,1000)
#      15     return W,b
#      16
#
# /tmp/ipykernel_20813/3653150324.py in updateWeights(X, W, b, size, lr, itrs)
#       1 def updateWeights(X,W,b,size,lr,itrs):
# ----> 2     A = 1/(1+np.exp(-(X.dot(W)+b)))
#       3     tmp = (A-Y.T)
#       4     tmp = np.reshape(tmp,size)
#       5     dW = np.dot(X.T,tmp)/size
#
# ValueError: shapes (150,4) and (150,) not aligned: 4 (dim 1) != 150 (dim 0)
